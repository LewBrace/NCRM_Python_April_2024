# %% [markdown]
# # Session 13 - part 2: Probability, t-tests, and chi-square tests
# ### SSI1002 - Programming for the Social Sciences
#
# ![image.png](attachment:image.png)
#
# ## Lewys Brace
# #### l.brace@exeter.ac.uk
